# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import re

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
if "uk_food" in mongo.list_database_names():
    # Switch to the "uk_food" database
    db = mongo["uk_food"]
    # Retrieve the 'establishments' collection.
    collection = db["establishments"]
    print("Switched to 'uk_food' database successfully.")
else:
    print("'uk_food' database not found. Make sure it has been imported.")
# Out:
# Switched to 'uk_food' database successfully.

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
hygiene_count = establishments.count_documents(query)
print("Number of establishments with a hygiene score of 20:", hygiene_count)

# Display the first document in the results using pprint
first_document = establishments.find_one(query)
print("First document with a hygiene score of 20:")
pprint(first_document)
# Out:
# Number of establishments with a hygiene score of 20: 41
# First document with a hygiene score of 20:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64b985d0526f7401b0d11ebd'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
num_rows = len(hygiene_df)
print("Number of rows in the DataFrame:", num_rows)

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(hygiene_df.head(10))
# Out:
# Number of rows in the DataFrame: 41
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64b985d0526f7401b0d11ebd   110681                  0
# 1  64b985d0526f7401b0d1223b   612039                  0
# 2  64b985d0526f7401b0d12546   730933                  0
# 3  64b985d0526f7401b0d1272e   172735                  0
# 4  64b985d0526f7401b0d12742   172953                  0
# 5  64b985d0526f7401b0d130e0   512854                  0
# 6  64b985d0526f7401b0d13303  1537089                  0
# 7  64b985d1526f7401b0d14828   155648                  0
# 8  64b985d1526f7401b0d14c73  1012883                  0
# 9  64b985d1526f7401b0d15481   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {
    "$and": [
        {"LocalAuthorityName": {"$regex": re.compile("London", re.IGNORECASE)}},
        {"RatingValue": {"$gte": 4}}
    ]
}

# Use count_documents to display the number of documents in the result
london_count = establishments.count_documents(query)
print("Number of establishments in London with a RatingValue greater than or equal to 4:", london_count)

# Display the first document in the results using pprint
first_document = establishments.find_one(query)
print("First document in London with a RatingValue greater than or equal to 4:")
pprint(first_document)

# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
num_rows = len(london_df)
print("Number of rows in the DataFrame:", num_rows)

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(london_df.head(10))
# Out:
# Number of establishments in London with a RatingValue greater than or equal to 4: 33
# First document in London with a RatingValue greater than or equal to 4:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
# ...

# %%
# Convert the result to a Pandas DataFrame
london_df = pd.DataFrame(list(establishments.find(query)))

# Display the number of rows in the DataFrame
num_rows = len(london_df)
print("Number of rows in the DataFrame:", num_rows)

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(london_df.head(10))
# Out:
# Number of rows in the DataFrame: 33
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  64b985d1526f7401b0d138d4   621707                  0
# 1  64b985d1526f7401b0d13bfb  1130836                  0
# 2  64b985d1526f7401b0d14748   293783                  0
# 3  64b985d1526f7401b0d15545  1315095                  0
# 4  64b985d1526f7401b0d1554c   294474                  0
# 5  64b985d1526f7401b0d15c50   294900                  0
# 6  64b985d1526f7401b0d17d61   293756                  0
# 7  64b985d1526f7401b0d18127   878523                  0
# 8  64b985d1526f7401b0d1813f   294606                  0
# 9  64b985d1526f7401b0d18142   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

# Define the search radius in degrees
degree_search = 0.01

# Define the query to find establishments with RatingValue of 5 within the specified latitude and longitude range
query = {
    "$and": [
        {"RatingValue": 5},
        {"Latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search}},
        {"Longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}}
    ]
}

# Find the establishments with RatingValue of 5 within the specified latitude and longitude range
results = list(collection.find(query))

# Sort the establishments based on their hygiene score (lowest first)
results.sort(key=lambda x: x.get("Scores", {}).get("Hygiene", 0))

# Calculate the distance of each establishment from 'Penang Flavours'
for establishment in results:
    establishment_latitude = float(establishment.get("Latitude"))
    establishment_longitude = float(establishment.get("Longitude"))
    distance = geodesic((latitude, longitude), (establishment_latitude, establishment_longitude)).kilometers
    establishment["Distance"] = distance

# Sort the establishments based on distance (nearest first)
results.sort(key=lambda x: x["Distance"])

# Display the top 5 establishments with RatingValue of 5, sorted by lowest hygiene score and nearest to 'Penang Flavours'
print("Top 5 establishments with RatingValue of 5, sorted by lowest hygiene score and nearest to 'Penang Flavours':")
for idx, establishment in enumerate(results[:5], 1):
    print(f"{idx}.")
    print("Name:", establishment["BusinessName"])
    print("Hygiene Score:", establishment.get("Scores", {}).get("Hygiene"))
    print("RatingValue:", establishment["RatingValue"])
    print("Location:", establishment["Location"]["AddressLine1"])
    print("Latitude:", establishment["Latitude"])
    print("Longitude:", establishment["Longitude"])
    print("Distance:", establishment["Distance"], "km")
    print()

# %%
# Convert result to Pandas DataFrame
proximity = establishments.find(query).sort(sort).limit(5)
proximity_df = pd.DataFrame(list(proximity))

print(proximity_df.head(10))

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {
        "$match": {"Scores.Hygiene": 0}
    },
    {
        "$group": {
            "_id": "$LocalAuthorityName",
            "count": {"$sum": 1}
        }
    },
    {
        "$sort": {"count": -1}
    }
]

# Execute the aggregation pipeline
poor_hygiene = establishments.aggregate(pipeline)

# Print the number of documents in the result
for doc in poor_hygiene:
    print(f"Number of establishments in '{doc['_id']}' with a hygiene score of 0: {doc['count']}")

# Print the first 10 results
pipeline_with_limit = pipeline + [{"$limit": 10}]
first_10_results = establishments.aggregate(pipeline_with_limit)

print("\nFirst 10 results:")
for doc in first_10_results:
    print(doc)

# %%
# Convert the result to a Pandas DataFrame
poor_hygiene_df = pd.DataFrame(list(establishments.aggregate(pipeline)))

# Display the number of rows in the DataFrame
num_rows = len(poor_hygiene_df)
print("Number of rows in the DataFrame:", num_rows)

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(poor_hygiene_df.head(10))
